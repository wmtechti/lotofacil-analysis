# %% [markdown]
# # 🎯 Análise Espacial Completa da Lotofácil
#
# Este notebook apresenta uma análise completa dos sorteios da Lotofácil usando o grid 5×5 do volante como domínio espacial.
#
# ## 📋 Conteúdo:
# 1. **Carregamento de Dados** - Overview dos resultados
# 2. **Heatmap do Grid 5×5** - Visualização de frequências
# 3. **Números Quentes/Frios** - Análise de desvios
# 4. **Rede de Co-ocorrência** - Pares que saem juntos
# 5. **Métricas Espaciais** - Dispersão e padrões
# 6. **Tendências Temporais** - Evolução ao longo do tempo
# 7. **Análise de Pares Fortes** - Super pares
# 8. **Conclusões e Insights**
#
# ---
#
# **Dataset**: 3.575 sorteios (29/09/2003 até presente)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
from pathlib import Path

# Configurações de visualização
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (14, 8)
plt.rcParams['font.size'] = 11

# Diretórios
OUT_DIR = Path("../out")
DATA_DIR = Path("../data")

print("✓ Bibliotecas carregadas com sucesso!")

# %%
# Carregar dados processados
heatmap_df = pd.read_csv(OUT_DIR / "heatmap_5x5.csv", index_col=0)
freq_linhas = pd.read_csv(OUT_DIR / "freq_linhas.csv")
freq_colunas = pd.read_csv(OUT_DIR / "freq_colunas.csv")
metrics_df = pd.read_csv(OUT_DIR / "metrics_por_sorteio.csv")
pares_df = pd.read_csv(OUT_DIR / "top_pares_coocorrencia.csv")
clusters_df = pd.read_csv(OUT_DIR / "clusters_dbscan_manhattan.csv")
hot_cold_df = pd.read_csv(OUT_DIR / "numeros_quentes_frios.csv")
trends_df = pd.read_csv(OUT_DIR / "tendencias_temporais.csv")
pares_forca = pd.read_csv(OUT_DIR / "pares_forca.csv")

print(f"✓ {len(metrics_df)} sorteios carregados")
print(f"✓ Heatmap shape: {heatmap_df.shape}")
print(f"✓ {len(pares_df)} pares de co-ocorrência")
print(f"✓ {len(hot_cold_df)} números analisados")

# %% [markdown]
# ## 2️⃣ Carregamento de Dados
#
# Carregando todos os resultados das análises já processadas.

# %% [markdown]
# ## 1️⃣ Import de Bibliotecas
#
# Carregando todas as bibliotecas necessárias para análise e visualização.
